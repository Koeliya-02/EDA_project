# %%
import pandas as pd 
df = pd.read_csv("combined_post_data_2_labels.csv")
print(df)
# Out:
#                                                     text  label
# 0      !!! RT @mayasolovely: As a woman you shouldn't...    0.0
# 1        " momma said no pussy cats inside my doghouse "    0.0
# 2      "@Addicted2Guys: -SimplyAddictedToGuys http://...    0.0
# 3      "@AllAboutManFeet: http://t.co/3gzUpfuMev" woo...    0.0
# 4      "@Allyhaaaaa: Lemmie eat a Oreo &amp; do these...    0.0
# ...                                                  ...    ...
# 81725  Gotta say,\nthe Apocalypse came early for Brow...    1.0
# 81726  "...because he refused to host a lesbian weddi...    1.0
# 81727            (((them))) ? are you referring to Jews?    1.0
# 81728                   (((Liberal))) Sexual Misconduct.    1.0
# 81729  (((((BREAKING)))))\n\nBRAND NEW Q POST!!! 1-26...    0.0
#
# [81730 rows x 2 columns]

# %%
import pandas as pd

count_4 = 0

l = []

for index, row in df.iterrows():
    if not isinstance(row[0], str):
        print(row[0])
        count_4 += 1
    elif not(row[1] == 1.0 or row[1] == 0.0):
        print(row)
        count_4 += 1
    else:
        l.append(row)
        
df_2 = pd.DataFrame(l)
print(count_4)
# Out:
# C:\Users\koush\AppData\Local\Temp\ipykernel_19032\3957275229.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if not isinstance(row[0], str):
# C:\Users\koush\AppData\Local\Temp\ipykernel_19032\3957275229.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif not(row[1] == 1.0 or row[1] == 0.0):
# text     Probably gonna piss off some #feminists
# label                                        NaN
# Name: 6867, dtype: object
# text     #yesallmen
# label            NaN
# Name: 6868, dtype: object
# ...

# %%
print(df_2)
# Out:
#                                                     text  label
# 0      !!! RT @mayasolovely: As a woman you shouldn't...    0.0
# 1        " momma said no pussy cats inside my doghouse "    0.0
# 2      "@Addicted2Guys: -SimplyAddictedToGuys http://...    0.0
# 3      "@AllAboutManFeet: http://t.co/3gzUpfuMev" woo...    0.0
# 4      "@Allyhaaaaa: Lemmie eat a Oreo &amp; do these...    0.0
# ...                                                  ...    ...
# 81725  Gotta say,\nthe Apocalypse came early for Brow...    1.0
# 81726  "...because he refused to host a lesbian weddi...    1.0
# 81727            (((them))) ? are you referring to Jews?    1.0
# 81728                   (((Liberal))) Sexual Misconduct.    1.0
# 81729  (((((BREAKING)))))\n\nBRAND NEW Q POST!!! 1-26...    0.0
#
# [80799 rows x 2 columns]

# %%
troll =[]
c1=0

normal = []
c2=0
c=0
for index, row in df_2.iterrows():
    c=c+1
    if row[1] == 0.0:
        normal.append(row)
        c1 = c1 +1
    elif row[1] == 1.0:
        troll.append(row)
        c2 = c2 +1
    else:
        print(row)

print(c1)
print(c2)
# Out:
# C:\Users\koush\AppData\Local\Temp\ipykernel_19032\1681724912.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[1] == 0.0:
# C:\Users\koush\AppData\Local\Temp\ipykernel_19032\1681724912.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif row[1] == 1.0:
# 57681
# 23118

# %%
print(c1+c2)
print(c)
# Out:
# 80799
# 80799

# %%
df_2.to_csv('cleaned_data.csv', index=False)
